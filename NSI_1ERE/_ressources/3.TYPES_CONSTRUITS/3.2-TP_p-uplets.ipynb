# %% [markdown]
# ---
#
# # <center>TP : p-uplets et p-uplets nommés</center>

# %% [markdown]
# ---
#
# ## Exercice 1 - Nom d'un mois _(2pts)_
#
# En utilisant un tuple (qui contiendra les noms des 12 mois de l'année), réalisez une fonction `nom_mois` qui à un entier compris entre 1 et 12 passé en paramètre renvoie le nom du mois correspondant. Par exemple :
#
# ```python
# nom_mois(2)
# # devra renvoyer 'Février'
# ```

# %%
def nom_mois(n):
    # à compléter

# %%
# Vérification
nom_mois(2)

# %% [markdown]
# ---
# ## Exercice 2 - Appartenance à un tuple _(4pts)_
#
# Lorsque `t` est un tuple, l’expression `x in t` permet de tester l’appartenance de la valeur de `x` à ce tuple. La réponse est booléenne.
#
# Mais on peut avoir besoin de plus d'informations comme l'indice de la valeur ou son nombre d'occurences dans le tuple.
#
# - Réalisez une fonction nommée `indice` qui renvoie l’indice de la première occurrence de son premier paramètre `x` dans le tuple `t` passé en second paramètre, si elle existe. Par exemple :
#
# ```python
# indice (4, (3, 1, 4, 1, 5, 9, 2))
# # doit renvoyer 2
# ```

# %%
def indice(x,t):
    # à compléter

# %%
# Vérification
indice (4, (3, 1, 4, 1, 5, 9, 2))

# %% [markdown]
# - Réalisez maintenant une fonction nommée `nbre_occurrences` qui renvoie le nombre d’occurrences du premier paramètre `x` dans le tuple `t` passé en second paramètre. Par exemple :
#
# ```python
# nbre_occurrences (1, (3,1,4,1,5,9,2))
# # doit renvoyer 2
# ```

# %%
def nbre_occurrences(x,t):
    # à compléter

# %%
# Vérification
nbre_occurrences (1, (3,1,4,1,5,9,2))

# %% [markdown]
# ---
# ## Exercice 3 - Insertion d’un élément dans un tuple _(3pts)_
#
# Réalisez une fonction nommée `insere` qui renvoie un tuple dans lequel l’élément `e` a été placé à l’indice `i` dans le tuple `t` avec `e`, `i` et `t` passés en paramètre. Par exemple :
#
# ```python
# insere(3,0,(1,4,1,5,9))
# # doit renvoyer (3,1,4,1,5,9)
# ```

# %%
def insere(e,i,t):
    # à compléter

# %%
# Vérification
insere(3,0,(1,4,1,5,9))

# %% [markdown]
# ---
#
# ## Exercice 4 - Suppression d’un élément dans un tuple _(3pts)_
#
# Réalisez une fonction nommée `supprime` qui pour un tuple`t` donné en paramètre renvoie un tuple contenant tous les éléments de `t` sauf celui d’un indice ```i``` lui aussi donné en paramètre. L'indice `i` doit être compris entre 0 et `len(t)-1`. Par exemple :
#
# ```python
# supprime((1,4,1,5,9),2)
# # doit renvoyer (1,4,5,9)
# ```

# %%
def supprime(t,i):
    # à compléter

# %%
# Vérification
supprime((1,4,1,5,9),2)

# %% [markdown]
# ---
#
# ## Exercice 5 - Tuple miroir _(4pts)_
#
# Réalisez une fonction nommée `renverse` qui renvoie un tuple contenant les éléments du tuple `t` passé en paramètre dans l’ordre inverse. Par exemple
#
# ```python
# l=tuple('Première 4')
# renverse(l)
# # doit renvoyer ('4', ' ', 'e', 'r', 'è', 'i', 'm', 'e', 'r', 'P')
# ```

# %%
def renverse(t):
    # à compléter

# %%
# Vérification
l=tuple('Première 4')
renverse(l)

# %% [markdown]
# ---
#
# ## Exercice 6 - Parité _(4pts)_
#
# La fonction `randint` du module `random` permet de choisir un nombre au hasard entre deux bornes `a` et `b` passées en paramètre. (les bornes sont inclues)

# %%
from random import randint
randint(0,99)

# %% [markdown]
# - Ecrivez une fonction nommée `entiers_au_hasard` paramétrée par un entier `n`, qui renvoie un tuple de longueur n d'entiers choisi entre 1 et 100.
#
# ```python
# entiers_au_hasard(10)
# # doit renvoyer par exemple (4, 63, 73, 59, 44, 72, 30, 52, 33, 38)
# ```

# %%
def entiers_au_hasard(n):
    # à compléter

# %%
# Vérification
entiers_au_hasard(10)

# %% [markdown]
# Voici maintenant la fonction `est_pair` qui permet de déterminer si un entier `n` passé en paramètre est pair.

# %%
def est_pair(n):
    return ( ( n % 2 ) == 0 )

# %%
est_pair(2)

# %%
est_pair(47)

# %% [markdown]
# - Réalisez une fonction `filtre_pair` paramétrée par un tuple d'entiers `t` et dont le résultat est le tuple obtenu en supprimant les entiers impairs du tuple `t`. Par exemple :
#
# ```python
# filtre_pair( (4, 63, 73, 59, 44, 72, 30, 52, 33, 38) )
# #doit renvoyer (4,44,72,30,52,38)
# ```

# %%
def filtre_pair(t):
    # à compléter

# %%
# Vérification
filtre_pair( (4, 63, 73, 59, 44, 72, 30, 52, 33, 38) )

# %% [markdown]
# ---
#
# # Exercice Bonus - Faire parler Tux
#
# ![tux](https://upload.wikimedia.org/wikipedia/commons/thumb/2/2b/Tux-simple.svg/154px-Tux-simple.svg.png)
#
#
# **Tux** est un manchot, mascotte du système d'exploitation _Linux_ depuis 1996. Contrairement à une croyance répandue, Tux n'est pas un pingouin : il s'agit d'une mauvaise traduction du faux-ami penguin. Vous allez écrire un programme pour lui faire dire ce que vous voulez.
#
#
# Tout d'abord, voici la variable TUX qui permet d'afficher le personnage Tux.

# %%
TUX = "   \\\n    \\\n        .--.\n       |o_o |\n       |:_/ |\n      //   \\ \\\n     (|     | )\n    /'\_   _/`\\\n    \___)=(___/"

# %%
print(TUX)

# %% [markdown]
# Le but du travail est de réaliser une procédure `tux_say`, paramétrée par un tuple de chaînes de caractères qui imprime dans une bulle les chaînes de caractères du tuple (chaque chaine correspondra à une ligne de la bulle).
# La largeur de la bulle devra s'adapter à la largeur de la plus grande des chaînes du tuple.
# Dans le cas où un tuple vide est passé en paramètre, un point d'interrogation apparaîtra dans la bulle.
#
# Pour réaliser cette fonction, nous allons procéder par étapesen créant des sous-fonctions :
# Nous allons avoir besoin de :
# - Connaître la plus longue chaîne de caractères dans un tuple
# - Créer une ligne composée d'un certain nombre de tirets
# - Créer une ligne contenant une chaîne de caractère encadrée par des |

# %% [markdown]
# ### Plus longue chaîne de caractères dans un tuple
# Réalisez une fonction `length_longest` qui prend en paramètre un tuple de chaînes de caractères et qui retourne la longueur de la plus grande chaîne dans le tuple. Si le tuple est vide, elle renvoie -1. Par exemple :
#
#
# ```python
# length_longest(("Cher-e-s étudiant-e-s,", "", "Vous programmez très bien !"))
# # doit renvoyer 27
#
# length_longest(())
# # doit renvoyer -1
# ```

# %%
def length_longest(t):
    # à compléter

# %%
# Vérification
length_longest(("Cher-e-s étudiant-e-s,", "", "Vous programmez très bien !"))

# %%
# Vérification
length_longest(())

# %% [markdown]
# ### Ligne composée de tirets
# Pour réaliser l'encadrement de la bulle dans laquelle Tux s'exprime nous allons avoir besoin de créer des lignes horizontales composées de n tirets et précédées par un espace. Elles constitueront les lignes supérieures et inférieures de la bulle.
#
# Réalisez une fonction `dash_line` qui prend en paramètre un entier `n` et retourne une chaîne de caractères composée d'un espace suivi par n tirets.
# ```python
# dash_line(35)
# # doit renvoyer ' -----------------------------------'
# ```

# %%
def dash_line(n):
    # à compléter

# %%
# Vérification
dash_line(35)

# %% [markdown]
# ### Réalisation de la procédure finale
# Maintenant que les trois fonctions précédentes ont été réalisées, il devient plus simple de réaliser la procédure tux_say en s'appuyant sur celles-ci.
#
# Réalisez la procédure `tux_say`.
#
# ```python
# tux_say (("Cher-e-s étudiant-e-s,", "", "Vous programmez très bien !"))
# # doit renvoyer
# ```
# ```
#  -----------------------------
# | Cher-e-s étudiant-e-s,      |
# |                             |
# | Vous programmez très bien ! |
#  -----------------------------
#    \
#     \
#         .--.
#        |o_o |
#        |:_/ |
#       //   \ \
#      (|     | )
#     /'\_   _/`\
#     \___)=(___/
#
# ```

# %%
def tux_say(t):
    # à compléter

# %%
# Vérification
tux_say (("Cher-e-s étudiant-e-s,", "", "Vous programmez très bien !"))
